# %%
from module_absenteeism import *

# %%
data = pd.read_csv('Absenteeism_new_data.csv')

# %%
data.head()
# Out:
#    ID  Reason for Absence        Date  Transportation Expense  \
# 0  22                  27  01/06/2018                     179
# 1  10                   7  04/06/2018                     361
# 2  14                  23  06/06/2018                     155
# 3  17                  25  08/06/2018                     179
# 4  14                  10  08/06/2018                     155
#
#    Distance to Work  Age  Daily Work Load Average  Body Mass Index  Education  \
# 0                26   30                  237.656               19          3
# 1                52   28                  237.656               27          1
# 2                12   34                  237.656               25          1
# 3                22   40                  237.656               22          2
# 4                12   34                  237.656               25          1
#
#    Children  Pets
# 0         0     0
# 1         1     4
# 2         2     0
# 3         2     0
# 4         2     0

# %%
model = Absenteeism_model('Model_portofolio','Scaler_portofolio')

# %%
model.load_and_cleaning_data('/content/Absenteeism_new_data.csv')

# %%
check = pd.read_csv('/content/data_preprocessed.csv')
check.head()
# Out:
#    reason1  reason2  reason3  reason4  Transportation Expense  \
# 0        0      0.0        0        1               -0.656180
# 1        1      0.0        0        0                2.086051
# 2        0      0.0        0        1               -1.017793
# 3        0      0.0        0        1               -0.656180
# 4        1      0.0        0        0               -1.017793
#
#    Distance to Work       Age  Daily Work Load Average  Body Mass Index  \
# 0         -0.268486 -1.005832                 -0.84769        -1.819736
# 1          1.483045 -1.321144                 -0.84769         0.069078
# 2         -1.211617 -0.375208                 -0.84769        -0.403126
# 3         -0.537952  0.570729                 -0.84769        -1.111431
# 4         -1.211617 -0.375208                 -0.84769        -0.403126
#
#    Education  Children      Pets  monday  thursday  tuesday  wednesday
# 0   2.576911 -0.913259 -0.587555       0         0        0          0
# ...

# %%
model.predicted_outputs()
# Out:
# /usr/local/lib/python3.8/dist-packages/sklearn/base.py:443: UserWarning: X has feature names, but LogisticRegression was fitted without feature names
#   warnings.warn(
# /usr/local/lib/python3.8/dist-packages/sklearn/base.py:443: UserWarning: X has feature names, but LogisticRegression was fitted without feature names
#   warnings.warn(
#     ID  Reason for Absence        Date  Transportation Expense  \
# 0   22                  27  01/06/2018                     179
# 1   10                   7  04/06/2018                     361
# 2   14                  23  06/06/2018                     155
# 3   17                  25  08/06/2018                     179
# 4   14                  10  08/06/2018                     155
# 5   28                  11  11/06/2018                     225
# 6   16                   7  13/06/2018                     118
# 7   22                  27  13/06/2018                     179
# 8   34                  26  15/06/2018                     118
# ...
